# %% [markdown]
# # **Project Name**    - **Hotel Booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# We selected Hotel Booking Analysis as our Capstone Project because we thought this topic may provide us new information about Hotel Industry which might be also useful to hotel owners.
# In this project we got one CSV file containing data about hotel bookings.
#
# At first as we started our project we faced lot of confusion about project and how to do it because this was our first project.So we started with looking at each database available to us & went through various columns available within databases & tried to make sense of what all data is available to us.
# We also discussed within ourselves and worked some ideas that which
# question we might want to answer from given data to get proper idea of how hotel industries bookings, Customer retention, cancellation varies during whole season or given period.
# So we started gaining insights by analyzing,exploring different aspects of data & doing some random eda,etc.After doing some random EDAs.We gained some confidence and we got the idea of how to move forward with the project so individually we started our project.
# In this project, we will try to predict the possibility of a booking for a hotel based on different factors and also try to predict if they cancelled the booking if the lead time/waiting time is more or any other such elements. The data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. From it, we can understand the customer’s’ behavior and it might help us make better decisions.
#
# The process of our analysis will be by the following step: Define our Business question, understanding the Datasets, Data preparation and wrangling, analyze the data, model the data and conclusion.
# * Defining the problem statement & Business Objective of the study.
# * Collection and preparation of data by Data Wrangling - data cleaning,structuring the correct data type, createing new variables,Handling outliers etc.
# * We will be analyzing some key metrics for hotel bookings & try to look through the data to analyze patterns associated with each segment
# * Performing EDA - By analyzing some key metrics for hotel bookings & try to look through the data to analyze patterns associated with each segment. And presenting the data in a easily comphrensible form to understand.
# * And last giving solution to our Business Objective & Problem Statement. Thus, concluding our porject.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Kalpesh-Nandedkar/Capstone-Project-1-Hotel-Booking-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# * Hotel industry is a very volatile industry and the bookings depend on variety of factors such as type of hotels, seasonality, days of week and many more. This makes analyzing the patterns available in the past data more important to help the hotels plan better. Using the historical data, hotels can perform various campaigns to boost the business. We can use the patterns to predict the future bookings.
#
# * We will be using the data available to analyze the factors affecting the hotel bookings. These factors can be used for reporting the trends and predict the future bookings & reduce the optimal number of booking cancellation.
#
# * This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **To increase the Bookings, reduce the customer cancellation rate & Increase the Retention of customer as well as to increase the optimal stay while procurring the optimal adr.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import date
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
hotel_df = pd.read_csv('/content/drive/MyDrive/AlmaBetter/Capstone Project/Capstone Project Python/Hotel Booking Analysis/Hotel Bookings.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
hotel_df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(hotel_df[hotel_df.duplicated()])
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
hotel_df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
plt.figure(figsize=(15, 8))
sns.heatmap(hotel_df.isnull(), cbar=False, yticklabels=False,cmap='viridis')
plt.xlabel("Name Of Columns")
plt.title("Missing values in column")
# Out:
# Text(0.5, 1.0, 'Missing values in column')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset given is a dataset from hotel industry, and we have to explore and analyze the data to discover important factors that govern the bookings.
#
# The goal is to analyze the dataset by exploring data provided under various column headings.
#
# The above dataset has 119390 rows and 32 columns. There are no null values in any columns except for 4 columns(children,country,agent,company). The dataset also have 31994 duplicate values

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hotel_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The columns and the data it represents are listed below:
# 1.   hotel : Hotel(Resort Hotel or City Hotel)
# 2.   **is_canceled :** Value indicating if the booking was canceled (1) or not (0)
# 3.   **lead_time :** Number of days before the actual arrival of the guests
# 4.   **arrival_date_year :** Year of arrival date
# 5.   **arrival_date_month :** Month of month arrival date
# 6.  **arrival_date_week_number :** Week number of year for arrival date
# 7.   **arrival_date_day_of_month :** Day of arrival date
# 8.   **stays_in_weekend_nights :** Number of weekend nights (Saturday or Sunday) spent at the hotel by the guests.
# 9.   **stays_in_week_nights :** Number of weeknights (Monday to Friday) spent at the hotel by the guests.
# 10.   **adults :** Number of adults among guests
# 11.   **children :** Number of children among guests
# 12.   **babies :** Number of babies among guests
# 13.   **meal :** Type of meal booked
# 14.   **country :** Country of guests
# 15.   **market_segment :** Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# 16.   **distribution_channel :** Name of booking distribution channel.The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# 17.   **is_repeated_guest :** Value indicating if the booking name was from a repeated guest (1) or not (0)
# 18.   **previous_cancellations :** Number of previous bookings that were cancelled by the customer prior to the current booking
# 19.   **previous_bookings_not_canceled :** Number of previous bookings not cancelled by the customer prior to the current booking
# 20.   **reserved_room_type :** Code for the type of room that was reserved by the customer.
# 21.   **assigned_room_type :** Code for the type of room assigned to the booking.
# 22.  **booking_changes :** Number of changes/amendments made to the booking
# 23.   **deposit_type :** Type of the deposit made by the guest
# 24.   **agent :** ID of travel agent who made the booking
# 25.   **company :** ID of the company that made the booking
# 26.   **days_in_waiting_list :** Number of days the booking was in the waiting list
# 27.   **customer_type :** Type of customer, assuming one of four categories
# 28.   **adr :** Average Daily Rate, as defined by dividing the sum of all lodging transactions by the total number of staying nights
# 29.   **required_car_parking_spaces :** Number of car parking spaces required by the customer
# 30.   **total_of_special_requests :** Number of special requests made by the customer
# 31.   **reservation_status :** Reservation status (Canceled, Check-Out or No-Show)
# 32.   **reservation_status_date :** Date at which the last reservation status was updated

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in hotel_df.columns.tolist():
  print("No. of unique values in ",i,"is",hotel_df[i].nunique(),".")
# Out:
# No. of unique values in  hotel is 2 .
# No. of unique values in  is_canceled is 2 .
# No. of unique values in  lead_time is 479 .
# No. of unique values in  arrival_date_year is 3 .
# No. of unique values in  arrival_date_month is 12 .
# No. of unique values in  arrival_date_week_number is 53 .
# No. of unique values in  arrival_date_day_of_month is 31 .
# No. of unique values in  stays_in_weekend_nights is 17 .
# No. of unique values in  stays_in_week_nights is 35 .
# No. of unique values in  adults is 14 .
# No. of unique values in  children is 5 .
# No. of unique values in  babies is 5 .
# No. of unique values in  meal is 5 .
# No. of unique values in  country is 177 .
# No. of unique values in  market_segment is 8 .
# No. of unique values in  distribution_channel is 5 .
# No. of unique values in  is_repeated_guest is 2 .
# No. of unique values in  previous_cancellations is 15 .
# No. of unique values in  previous_bookings_not_canceled is 73 .
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
# Firstly lets make a copy of our dataframe to work on
hotel_df1=hotel_df.copy()

# %% [markdown]
# # DATA CLEANING

# %%
# Checking for duplicate Values
hotel_df1[hotel_df1.duplicated()].shape
# Out:
# (31994, 32)

# %%
# Dropping duplicate values
hotel_df1.drop_duplicates(inplace = True)

# %%
# Checking for the null values in dataset
hotel_df1.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# company               82137
# agent                 12193
# country                 452
# children                  4
# reserved_room_type        0
# assigned_room_type        0
# dtype: int64

# %% [markdown]
# Since, company and agent columns have comany number and agent numbers as data. There may be some cases when customer didnt booked hotel via any agent or via any company. So in that case values can be null under these columns.
# We will replace null values by 0 in these columns

# %%
# checking company data
hotel_df1['company'].unique()
# Out:
# array([ nan, 110., 113., 270., 178., 240., 154., 144., 307., 268.,  59.,
#        204., 312., 318.,  94., 174., 274., 195., 223., 317., 281., 118.,
#         53., 286.,  12.,  47., 324., 342., 373., 371., 383.,  86.,  82.,
#        218.,  88.,  31., 397., 392., 405., 331., 367.,  20.,  83., 416.,
#         51., 395., 102.,  34.,  84., 360., 394., 457., 382., 461., 478.,
#        386., 112., 486., 421.,   9., 308., 135., 224., 504., 269., 356.,
#        498., 390., 513., 203., 263., 477., 521., 169., 515., 445., 337.,
#        251., 428., 292., 388., 130., 250., 355., 254., 543., 531., 528.,
#         62., 120.,  42.,  81., 116., 530., 103.,  39.,  16.,  92.,  61.,
#        501., 165., 291., 290.,  43., 325., 192., 108., 200., 465., 287.,
#        297., 490., 482., 207., 282., 437., 225., 329., 272.,  28.,  77.,
#        338.,  72., 246., 319., 146., 159., 380., 323., 511., 407., 278.,
#         80., 403., 399.,  14., 137., 343., 346., 347., 349., 289., 351.,
# ...

# %%
# Filling NaN value with 0 as No Hotel where Booked through Company
hotel_df1['company'].fillna(0, inplace = True)

# %%
# checking agent data
hotel_df1['agent'].unique()
# Out:
# array([ nan, 304., 240., 303.,  15., 241.,   8., 250., 115.,   5., 175.,
#        134., 156., 243., 242.,   3., 105.,  40., 147., 306., 184.,  96.,
#          2., 127.,  95., 146.,   9., 177.,   6., 143., 244., 149., 167.,
#        300., 171., 305.,  67., 196., 152., 142., 261., 104.,  36.,  26.,
#         29., 258., 110.,  71., 181.,  88., 251., 275.,  69., 248., 208.,
#        256., 314., 126., 281., 273., 253., 185., 330., 334., 328., 326.,
#        321., 324., 313.,  38., 155.,  68., 335., 308., 332.,  94., 348.,
#        310., 339., 375.,  66., 327., 387., 298.,  91., 245., 385., 257.,
#        393., 168., 405., 249., 315.,  75., 128., 307.,  11., 436.,   1.,
#        201., 183., 223., 368., 336., 291., 464., 411., 481.,  10., 154.,
#        468., 410., 390., 440., 495., 492., 493., 434.,  57., 531., 420.,
#        483., 526., 472., 429.,  16., 446.,  34.,  78., 139., 252., 270.,
#         47., 114., 301., 193., 182., 135., 350., 195., 352., 355., 159.,
# ...

# %%
# Filling NaN value with 0 as No Hotel where Booked through a agent
hotel_df1['agent'].fillna(0, inplace = True)

# %% [markdown]
# Next column with missing value is 'country'. This column represents the country of origin.
# Since, this column has datatype of string. We will replace the missing value in the 'country' column as "Other".

# %%
# checking Country data
hotel_df1['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
# Filling nan value with "Other" as the given country was not in a hotel given list.
hotel_df1['country'].fillna('Other', inplace = True)

# %%
# checking children data
hotel_df1['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %% [markdown]
# This column 'children' has 0 as value which means 0 children were present in group of customers who made that transaction.
# So, 'nan' values are the missing values due to error of recording data.
#
# We will replace the null values under this column with mean value of children.

# %%
# Filling nan value with 0 as there are no number for present.
hotel_df1['children'].fillna(hotel_df1['children'].mean(), inplace = True)

# %%
# Checking the dataset of 'adults' column
hotel_df1['adults'].unique()
# Out:
# array([ 2,  1,  3,  4, 40, 26, 50, 27, 55,  0, 20,  6,  5, 10])

# %% [markdown]
# There are some rows with total number of adults equal to zero. So we will remove such rows.
# As there is no permission to anyone who is not adult or without an adult for entry in a hotel rooms.

# %%
#Checking the shape of 'adults' column having 0 as value
hotel_df1[hotel_df1['adults']==0].shape
# Out:
# (385, 32)

# %%
# Removing Values as 0 from dataset
hotel_df1.drop(hotel_df1[hotel_df1['adults']==0].index, inplace = True)

# %%
hotel_df1['adults'].unique()
# Out:
# array([ 2,  1,  3,  4, 40, 26, 50, 27, 55, 20,  6,  5, 10])

# %% [markdown]
# ##Changing data types of given data to proper data type

# %%
hotel_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87011 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87011 non-null  object
#  1   is_canceled                     87011 non-null  int64
#  2   lead_time                       87011 non-null  int64
#  3   arrival_date_year               87011 non-null  int64
#  4   arrival_date_month              87011 non-null  object
#  5   arrival_date_week_number        87011 non-null  int64
#  6   arrival_date_day_of_month       87011 non-null  int64
#  7   stays_in_weekend_nights         87011 non-null  int64
#  8   stays_in_week_nights            87011 non-null  int64
#  9   adults                          87011 non-null  int64
#  10  children                        87011 non-null  float64
#  11  babies                          87011 non-null  int64
# ...

# %%
# changing datatype of column 'reservation_status_date' to date_type.
hotel_df1['reservation_status_date'] = pd.to_datetime(hotel_df1['reservation_status_date'], format = '%Y-%m-%d')

# %%
# Converting datatype of columns 'children', 'company' and 'agent' from float to int.
hotel_df1[['children','company','agent']] = hotel_df1[['children','company','agent']].astype('int64')

# %%
# checking for the outlier in the adr
plt.figure(figsize=(7,5))
sns.boxplot(hotel_df1['adr'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# From above we can see that there is a outlier in adr which will result in poor chart as well as for further calculation. So, we will remove it

# %%
# dropping the outlier from the adr dataset
hotel_df1.drop(hotel_df1[hotel_df1['adr'] > 5000].index, inplace = True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# * Based upon the initial assessment we found that the data was pretty much clean except for some missing values in a few columns. Upon using the info() method, we draw out the following key insights about the data:-
#   1.	The dataset has a shape of (119390, 32) which means that it contains approximately 1.2 lakh rows and 32 columns.
#   2.	Our Dataset has 4 columns with float64 dtype, 16 columns with int64 dtype, and 12 columns with object dtype.
#   3.	In our Dataset, we observed null values in the following columns:
#     * 4 null values in the children column
#     *	488 null values in the country column
#     *	16,340 null values in the agent column
#     *	112,593 null values in the company column
#
# * Then we made a copy of original dataset to work on.
# * Then we proceed for data cleaning init,
#     1. We Checked & deleted all duplicated rows in Dataset.
#     2. We checked for all null/missing values & replace it with a proper & operable Values.
# * Then we changed the dataypes of columns to suitable dataypes.
# * As adr is the most important factor throughout the dataset. We check for the outlier in adr, As there was only one outlier in it we remove it for better understanding the relationship of adr with other dataset

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #**Univariate Analysis**

# %% [markdown]
#  # **Q1. In the Hotel Business which Type of Hotel has Most Booking ?**

# %%
# grouping the hotel by type
hotel_type = hotel_df1.groupby('hotel')
# taking the percentage per hotel type
Booking_perc = pd.DataFrame(hotel_type.size() / hotel_df1.shape[0]*100).reset_index().rename(columns={0:'hotel_booked'})
data = Booking_perc['hotel_booked']
# plotting the pie diagram for visualization
plt.figure(figsize = (7,7))
labels= Booking_perc['hotel']
plt.pie(x=data, explode=[0.05, 0.05], autopct="%1.1f%%", shadow=True, labels=labels, pctdistance=0.5)
plt.title("Pie Chart  representing which hotel people Booked most", fontsize = 20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart expresses a part-to-whole relationship in your data. It's easy to explain the percentage comparison through area covered in a circle with different colors. Where differenet percentage comparison comes into action pie chart is used frequently. So, I used Pie chart and which helped me to get the percentage comparision of the dependant variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above pie diagram we can say that the 'City Hotel' Type has more percent(61%) of booking than the 'Resort Hotel' Type(39%). Most cutomer choose city hotel over resort hotel, hence city hotel is much busier than resort hotel.

# %% [markdown]
# #**Q2. How many booking were made by repeated guest ?**

# %%
# Grouping by with respect to repeated guest
repeated_guest = hotel_df1.groupby('is_repeated_guest')

# calculating repeated guest percentage
repeated_guest_perc = pd.DataFrame(repeated_guest.size() / hotel_df1.shape[0]*100).reset_index().rename(columns={0:'Booking %'})
repeated_guest1 = repeated_guest_perc['Booking %'].rename({0:'not repeated guest', 1 : 'repeated guest'})
repeated_guest2 =  pd.DataFrame(repeated_guest1)
repeated_guest2
# Out:
#                     Booking %
# not repeated guest  96.134927
# repeated guest       3.865073

# %%
# plot a pie chart to show % of repeated guests
hotel_df1['is_repeated_guest'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)
plt.title("% of Repeated Guest")
plt.show()

# %% [markdown]
# **Chart Represents :**
#
# *   0= Not Repeated Guest
# *   1= Repeated Guest

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart expresses a part-to-whole relationship in your data. It's easy to explain the percentage comparison through area covered in a circle with different colors. Where differenet percentage comparison comes into action pie chart is used frequently. So, I used Pie chart and which helped me to get the percentage comparision of the dependant variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Only a very small percentage (**3.9%**) of bookings are made by repeated guests.That means customer retention rate for hotels are very low.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The Hotels customer retention rate is very low.Hence, Hotels must try to come up with different scheme or discount for repeated customer as advertising or campaigning for new customer may cost alot of time as well as money.So they should try little focusing on increasing retention rate.

# %% [markdown]
# # **Q3.What is the Percentage of Booking Cancellation ?**

# %%
# Pie chart representing the cancelled booking %
hotel_df1['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)
plt.title("Cancellation and non Cancellation")
plt.show()

# %% [markdown]
# **Chart Represents :**
#
# *   0 = not cancled
# *   1 = canceled

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart expresses a part-to-whole relationship in your data. It's easy to explain the percentage comparison through area covered in a circle with different colors. Where differenet percentage comparison comes into action pie chart is used frequently. So, I used Pie chart and which helped me to get the percentage comparision of the dependant variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above we can say that more than quarter(**27.5%**) of the bookings were cancelled and about **72.5%** of people did not cancel their booking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The Hotels must try to address the problem regarding hotel cancellation as more than 25% of customer are cancelling their booking which reduces of about $\frac {1}{4}th$ of adr which impact alot. For this while cancelling the booking the hotel must provide or include a Feedback form so that they can have a idea as why the customer are cancelling the booking & on which aspect they can improve, so there cancellation rate comes down.

# %% [markdown]
# #**Q4. Which room type is most in demand ?**

# %%
# Grouping on basis of hotel type & getting count on assigned_room_type
total_room_type = hotel_df1.groupby(['hotel'])['assigned_room_type'].value_counts()
pd.DataFrame(total_room_type)
# Out:
#                                  assigned_room_type
# hotel        assigned_room_type
# City Hotel   A                                33340
#              D                                13194
#              E                                 2046
#              F                                 1970
#              B                                 1473
#              G                                  688
#              K                                  185
#              C                                  158
# Resort Hotel A                                12906
#              D                                 9222
#              E                                 5144
#              C                                 2002
#              G                                 1806
#              F                                 1657
#              H                                  706
#              I                                  353
# ...

# %%
# Plotting the bar chart for visualization
plt.figure(figsize = (7,7))
sns.countplot(x = hotel_df1['assigned_room_type'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the total count of different room types, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Room type **'A'** is most in demand as well as most popular amoung customers followed by Room type **'D'**, **'E'** respectively.

# %% [markdown]
# # **Q5. Which is the most common distribution channel for hotel booking?**

# %%
# Total number of booking from each Distribution Channel
distribution_channel = hotel_df1.groupby('distribution_channel')
distribution_channel_df = pd.DataFrame(distribution_channel.size()).rename(columns = {0:"Total Number of Bookings"})
distribution_channel_df
# Out:
#                       Total Number of Bookings
# distribution_channel
# Corporate                                 5062
# Direct                                   12921
# GDS                                        181
# TA/TO                                    68841
# Undefined                                    5

# %%
# Total Percent of booking from each Distribution Channel
dc_percent_df = pd.DataFrame((distribution_channel.size()/hotel_df1.shape[0])*100).reset_index().rename(columns={0:"Total Percent Booking"})
dc_percent_df
# Out:
#   distribution_channel  Total Percent Booking
# 0            Corporate               5.817722
# 1               Direct              14.850017
# 2                  GDS               0.208022
# 3                TA/TO              79.118492
# 4            Undefined               0.005746

# %%
# Plotting Total booking from each Distribution Channel as bar chart
distribution_channel_df.plot.bar(figsize=(8,7))
plt.ylabel('Total Number of Bookings')
plt.grid()
plt.show()
# Plotting the distribution percentage on pie chart
dc_percent_df
plt.figure(figsize = (8,8))
data = dc_percent_df['Total Percent Booking']
labels = dc_percent_df['distribution_channel']
plt.pie(x=data, autopct="%.2f%%", explode=[0.05]*5, labels=labels, pctdistance=0.5)
plt.title("Total Booking Percent by each distribution channels", fontsize=14);
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have used two charts here, first one is a bar chart and secondly pie chart.
#
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the total booking count done by different distribution channel, I have used Bar Chart.
#
# A pie chart expresses a part-to-whole relationship in your data. It's easy to explain the percentage comparison through area covered in a circle with different colors. Where differenet percentage comparison comes into action pie chart is used frequently. So, I used Pie chart and which helped me to get the percentage comparision of different distribution channel with respect to their total booking percent done by each of them

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can see that the most of guest are making reservation through TA/TO channels which is travel agency and tour operator.Than the second most used channel is direct. TA/TO is the most popular distribution channel for hotel booking.It is giving more than 79% of Booking alone.
# While Direct booking is about 14.85% & Corporate is giving 5.82% of booking only.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can see that TA\TO is the most popular & most influtential booking channel above all.The hotels should offer them more commission or attractive deals to increase their hotel booking.

# %% [markdown]
# #**Q6. In which month most of the bookings happened ?**

# %%
# groupby arrival_date_month and taking the hotel count
bookings_by_months_df= hotel_df1.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts"})
# Create list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# creating df which will map the order of above months list without changing its values.
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
# sorting by arrival_date_month
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')

bookings_by_months_df
# Out:
#    arrival_date_month  Counts
# 4             January    4667
# 3            February    6065
# 7               March    7472
# 0               April    7879
# 8                 May    8329
# 6                June    7745
# 5                July   10011
# 1              August   11210
# 11          September    6671
# 10            October    6905
# 9            November    4967
# 2            December    5089

# %%
# set plot size
plt.figure(figsize=(15,7))

#pltting lineplot on x- months & y- booking counts
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['Counts'])

# set title for the plot
plt.title('Number of bookings across each month')
#set x label
plt.xlabel('Month')
#set y label
plt.ylabel('Number of bookings')
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line graphs or line charts are best when you want to show how the value of something changes over time, or compare how several things change over time relative to each other.
# Line graphs are common and effective charts because they are simple, easy to understand, and efficient.
# So I used line chart to plot the total booking with respect to month of year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above we can conclude that between June & september the most number of customer books hotel in that **August** is the peak for the customer to visit hotel. While November & January has the least number of bookings.The month of March to May has the average amount of bookings.

# %% [markdown]
# #**Q7. Which type of food is mostly preferred by the guests ?**

# %%
# counting the total the no. of meals ordered by the customers 
hotel_df1['meal'].value_counts()

# Plotting bar chart representing the prefered meal type by most customer 
# Setting the figsize
plt.figure(figsize=(12,6))
sns.countplot(x=hotel_df1['meal'])
# Setting the x-label
plt.xlabel('Meal Type')
# Setting the y-label
plt.ylabel('Count')
# Setting the title of the chart
plt.title("Preferred Meal Type")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# **Chart Represents :**
#
# Types of meal in hotels:
#
# * BB - (Bed and Breakfast)
# * HB- (Half Board)
# * FB- (Full Board)
# * SC- (Self Catering)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
# To show which type of meal is ordered how many times by customers or the total count of most prefered meal type ordered by customer, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * So the most preferred meal type by the guests is BB( Bed and Breakfast)
# * HB- (Half Board) and SC- (Self Catering) are equally preferred.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotels must Pre-Prepped material required for BB( Bed and Breakfast) type Meal  & put it on standby all the time to reduce the delay time and better time management and also buy more ingredients which required for preparing BB type meal and average amount for HB & SC type. Thus reducing the Wastage of Materail & reducing the Material Cost. Which will result in less wastage, better time management & increase in revenue.

# %% [markdown]
# #**Q8. What is the percentage of people required car parking spaces ?**

# %%
# Plotting pie chart for the total no. of request receive by the hotels for car parking space
hotel_df1['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct='%1.1f%%',shadow=False,figsize=(10,7),fontsize=15,labels=None)
# Labelling according to column data frame
labels=hotel_df1['required_car_parking_spaces'].value_counts().index
# setting title for the chart
plt.title('% People required car parking spaces')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
plt.show()

# %% [markdown]
# **Chart Represents:**
#
# **0** - Guest doesn't required a parking space or No request came regarding Parking space required.
#
# **1** - Customer required single parking space or parking space required equivalent for one car.
#
# **2** - Customer required Two parking space or parking space required equivalent for Two cars.
#
# **3** - Customer required Three parking space or parking space required equivalent for Three cars.
#
# **8** - Customer required Eight parking space or parking space required equivalent for Eight cars.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart expresses a part-to-whole relationship in your data. It's easy to explain the percentage comparison through area covered in a circle with different colors. Where differenet percentage comparison comes into action pie chart is used frequently. So, I used Pie chart and which helped me to get the percentage comparision of how many people required car parking space.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 91.6 % guests did not required the parking space. only 8.4 % guests required only 1 parking space. Thus Hotel does not have to worry about extra parking space or to manage a large area for parking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can see that very small percentage of people required parking space.Thus Hotels can utilize this Extra space available to conduct some Party\events or entertainment events on the space accordingly as a advertisement campaign to increase the booking or for increasing retention rate.

# %% [markdown]
# #**Q9. Which Agent made the most bookings ?**

# %%
# return highest bookings made by agents
highest_bookings= hotel_df1.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)

# taking top 10 bookings made by agent
top_ten_highest_bookings=highest_bookings[:10]

top_ten_highest_bookings
# Out:
#      agent  Most_Bookings
# 9        9          28546
# 174    240          13028
# 0        0          12124
# 14      14           3326
# 7        7           3290
# 183    250           2779
# 175    241           1644
# 27      28           1493
# 8        8           1380
# 1        1           1228

# %%
#Visualizaing the graph

plt.figure(figsize=(15,8))
sns.barplot(x=top_ten_highest_bookings['agent'],y=top_ten_highest_bookings['Most_Bookings'],order=top_ten_highest_bookings['agent'])
plt.xlabel('Agent No')
plt.ylabel('Number of Bookings')
plt.title("Most Bookings Made by the agent")
# Out:
# Text(0.5, 1.0, 'Most Bookings Made by the agent')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show which agent made the most number of bookings, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Agent ID no. : 9** made most of the bookings followed by Agent Id No. 240 & 0.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 75% of the bookings are done by just 8 agents.Therefore there is immense scope to increase bookings by other agents .Also special care needs to be taken to provide best services to these top agents providing most business.They should be offerred some increase commission rate or equivalent amount of some other offers to increase the bookings.

# %% [markdown]
# # **Q10. Top 10 countries from where most people booked the hotels.**

# %%
# value counting of total no. of people visited to each country
top_10_country = hotel_df1['country'].value_counts().head(10)
top_10_country_hotel_booked = pd.DataFrame(top_10_country).reset_index().rename(columns={'index': 'Country','country':'No. of Bookings'})
top_10_country_hotel_booked
# Out:
#   Country  No. of Bookings
# 0     PRT            27311
# 1     GBR            10409
# 2     FRA             8798
# 3     ESP             7230
# 4     DEU             5372
# 5     ITA             3052
# 6     IRL             3011
# 7     BEL             2065
# 8     BRA             1983
# 9     NLD             1901

# %%
# creating list of top 10 countries from where most booking happens
top_10 = hotel_df1[hotel_df1['country'].isin(["PRT","GBR","FRA","ESP","DEU","ITA","IRL",
                         "BEL","BRA","NLD"])]

# %%
# creating visualization plot for top 10 countries
plt.figure(figsize=(12,4))
sns.countplot(x='country', data= top_10)
plt.ylabel('No. of People')
plt.title('People from top travelling countries')
plt.grid()
plt.show()

# %% [markdown]
# Chart Represents :-
#
# Abbreviations of Country :-
# * PRT- Portugal
# * GBR- Great Britain
# * FRA- France
# * ESP- Spain
# * DEU - Germany
# * ITA -Itlay
# * IRL - Ireland
# * BEL -Belgium
# * BRA -Brazil
# * NLD-Netherlands

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show from which country most people booked hotel, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As we can see, Portugal tops the list with more than 25,000 of the guest booking from these country, followed by – Great Britain with more than 10,000 guest.Followed by France & Spain.
# Majority of the guests are from European Countries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can see that there are alot of countries from where there are very less amount of footfall, Thus we need to address that issue as why its very less & how should we proceed with advertising campaign at such countries.

# %% [markdown]
# #**BIVARIATE AND MULTIVARIATE ANALYSIS**

# %% [markdown]
# # **Q1. Which Hotel generate more revenue ?**

# %%
# Total Revenue Generated by each hotel
revenue = hotel_type['adr']
revenue_df = pd.DataFrame(revenue.size()).rename(columns= {"adr":"Total Revenue generated"})
revenue_df
# Out:
#               Total Revenue generated
# hotel
# City Hotel                      53054
# Resort Hotel                    33956

# %%
# Average revenue generated by each hotel
avg_revenue = hotel_type['adr'].agg(np.mean).reset_index().rename(columns = {'adr':'Average Revenue'})
avg_revenue.set_index('hotel', inplace = True)
avg_revenue
# Out:
#               Average Revenue
# hotel
# City Hotel         111.297556
# Resort Hotel        99.059517

# %%
# Plotting  Avg adr generated by each hotel
avg_revenue.plot.bar()
plt.ylabel('Avg. Revenue Generated')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the total booking with respect to type of hotel(Resort or City), I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart we can say that the Average Revenue generated by city hotel is more than resort hotel. More the ADR more is the revenue.

# %% [markdown]
# # **Q2.Which Hotel has more Booking Cancellation Rate?**

# %%
# Calculating Total Cancelled Booking in Hotels
Booking_cancelled = hotel_df1[hotel_df1['is_canceled'] == 1]
total_cancel = Booking_cancelled.groupby('hotel')
total_cancel_df = pd.DataFrame(total_cancel.size()).rename(columns = {0:'Total Cancelled Booking'})

# Total No. Of Hotels
total_hotel = hotel_df1.groupby('hotel')
total_hotel_df = pd.DataFrame(total_hotel.size()).rename(columns = {0:'Total Number of Bookings'})
Total_df = pd.concat([total_cancel_df,total_hotel_df], axis =1)

# Total Percent of Booking Cancelled
Total_df['Percent Cancelled Booking'] = (Total_df['Total Cancelled Booking']) / (Total_df['Total Number of Bookings']) * 100
Total_df
# Out:
#               Total Cancelled Booking  Total Number of Bookings  \
# hotel
# City Hotel                      15953                     53054
# Resort Hotel                     7974                     33956
#
#               Percent Cancelled Booking
# hotel
# City Hotel                    30.069363
# Resort Hotel                  23.483331

# %%
Total_Cancelled = Total_df[['Total Cancelled Booking','Total Number of Bookings']]
Percent_cancelled = Total_df['Percent Cancelled Booking']
# Plot chart for Number of Cancelled Booking
Total_Cancelled.plot.bar()
plt.title('Total Number Of Cancelled Booking', fontsize=15)
plt.ylabel('Total Customer')
plt.grid()
plt.show()
# Plot chart for Total Percentage of Cancelled Booking
Percent_cancelled.plot.bar()
plt.title('Total Percent Of Booking Cancelled', fontsize=15)
plt.ylabel('Total % of Booking Cancelled')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this I have used two graphs first shows the Total count & Second the total percentage.
#
# The bar graph is used to compare the items between different groups over time. Bar graphs are used to measure the changes over a period of time. When the changes are larger, a bar graph is the best option to represent the data.
#
# Thus, I have used the bar plot to show the total number of booking get cancelled.
#
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the average percentage of total % of booking cancelled, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above Bar Chart we can observe that City Hotel has about 30% of cancellation rate while booking cancellation rate for Resort Hotel is around 23%. That means People cancelled more booking for city hotel than resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Customers Booking cancellation is one of the most important factor in hotel business. As Hotels have spend a large amount of money on advertisement, different campaign\Events & Smooth function of customer transactions & their comfort. While in such if a customer cancelled the booking the hotel doesn't had the slightest idea as why?
#
# Thus to avoid these kind of situation & to reduce the cancellation rate the hotels should or must include a Feedback Form while cancelling the Booking, so the hotels could address or resolve that issue if any arise & Improve or make any changes to reduce the booking cancellation rate.

# %% [markdown]
# #**Q3. Which room type generates more adr ?**

# %%
# Grouping the Data with respect to hotel type and room type
hotel_room_type = hotel_df1.groupby(['assigned_room_type','hotel'])

# %%
# Taking the avg. of adr column & renaming it
avg_revenue_room_type = hotel_room_type['adr'].agg(np.mean).reset_index().rename(columns = {'adr':'Average Revenue'})
avg_revenue_room_type.set_index('assigned_room_type')
avg_revenue_room_type
# Out:
#    assigned_room_type         hotel  Average Revenue
# 0                   A    City Hotel        99.692069
# 1                   A  Resort Hotel        85.769595
# 2                   B    City Hotel        96.861378
# 3                   B  Resort Hotel       101.749119
# 4                   C    City Hotel       102.410190
# 5                   C  Resort Hotel       118.336459
# 6                   D    City Hotel       123.803480
# 7                   D  Resort Hotel        88.149835
# 8                   E    City Hotel       144.601017
# 9                   E  Resort Hotel       109.211479
# 10                  F    City Hotel       178.745873
# 11                  F  Resort Hotel       122.106451
# 12                  G    City Hotel       185.097558
# 13                  G  Resort Hotel       160.952492
# 14                  H  Resort Hotel       171.881530
# 15                  I  Resort Hotel        41.264278
# 16                  K    City Hotel        72.410919
# ...

# %%
# Visualizing the room type with respect to avg. adr
plt.figure(figsize = (7,7))
sns.barplot(x = avg_revenue_room_type['assigned_room_type'], y = avg_revenue_room_type['Average Revenue'], hue = avg_revenue_room_type['hotel'])
plt.title('Plot representing avg. adr generated by each distribution channel')
plt.grid()
plt.show()
# plotting which room type is most in demand
plt.figure(figsize = (7,7))
sns.countplot(x = hotel_df1['assigned_room_type'])
plt.title('Room type most favourable by guest')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this I have used two graphs first shows the Avg.adr with respect to hotel type & Second the total booking for each room type.
#
# The bar graph is used to compare the items between different groups over time. Bar graphs are used to measure the changes over a period of time. When the changes are larger, a bar graph is the best option to represent the data.
#
# Thus, I have used the bar plot to show the average revenue generated by each hotel with respect to different room types.
#
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the count of total booking done for each type of hotel, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Although Room type 'A' is most in demand & most popular in customers, Room type 'G' & 'F' generates highest adr for City Hotels while Room type 'H' & 'G' generates highest adr for Resort Hotels despite both room types having the lowest booking rate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From above we can see that while having the lowest booking rate for the room type 'F','G' & 'H' they provides the highest adr of all. Thus we should tend or provides some attractive offers(e.g. giving complementary Breakfast or Drinks) to the customers to booked this type of room.

# %% [markdown]
# # **Q4. Which hotel has high chance that its customer will return for another stay?**

# %%
# Calculating the total number of customer return to same hotel
repeat_guest = hotel_df1[hotel_df1['is_repeated_guest'] ==1]
repeated_guest = repeat_guest.groupby('hotel')
repeat_guest_df = pd.DataFrame(repeated_guest.size()).rename(columns = {0:"Repeated Guest"})
repeat_guest_df

total_repeat_df = pd.concat([repeat_guest_df,total_hotel_df],axis = 1)

# Total Percent of Repeated Guests
total_repeat_df['Repeated guest Percent'] = (total_repeat_df['Repeated Guest']) / (total_repeat_df['Total Number of Bookings']) * 100
total_repeat_df
# Out:
#               Repeated Guest  Total Number of Bookings  Repeated guest Percent
# hotel
# City Hotel              1656                     53054                3.121348
# Resort Hotel            1707                     33956                5.027094

# %%
# Plot Chart for Total Number of Repeated Guest
total_repeat_df['Repeated guest Percent'].plot.bar()
plt.title('Guests Return to Same Hotel for another stay', fontsize=15)
plt.ylabel('Percentage of Repeated Guest')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the average percentage of repeated customers with respect to hotel types, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above percent chart we can say that very few people return to same hotel while with respect to that people prefers more to resort hotel than city hotel.
#
# *   City Hotels has customer retention rate of about 3.12%
# *   Resort Hotels has customer retention rate of about 5.02%

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Customer Retention is extremely important for any business.For many Hotel Owners, retaining high profitable customers is the number one business goal.
#
# In this highly competitive market acquring a new customer costs alot around 20 -25 times more than to retaining a existing customer.So,
# Customer retention is more important than customer acquisition.
#
# From above we can see that the both types of hotels has very low customer retention rate thus they need to address such major problem & provide the repeated customers with attractive deals such as some % of discount while booking 2nd/3rd time or giving them complimentary BB, And keeping in touch with them by sending the Thanking message, Celebration message or Some attractive holidays deals.

# %% [markdown]
# #**Q5. Which Hotel does people prefer for longer Stayed  ?**

# %%
hotel_df1['Total_stay'] = hotel_df1['stays_in_weekend_nights'] + hotel_df1['stays_in_week_nights']

# %%
not_cancel = hotel_df1[hotel_df1['is_canceled'] == 0]
longer_stay = not_cancel[not_cancel['Total_stay'] < 16]
plt.figure(figsize = (15,5))
sns.countplot(x = longer_stay['Total_stay'], hue = longer_stay['hotel'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar graph is used to compare the items between different groups over time. Bar graphs are used to measure the changes over a period of time. When the changes are larger, a bar graph is the best option to represent the data.
#
# Thus, I have used the bar plot to show the optimal stay lenght guest preferred more.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# For long duration People prefers Resort Hotel while for short duration People mostly prefers City Hotel more.
#
#
# 1.   Optimal stay duration in city hotel is less than 5 days
# 2.   Optimal stay duration in Resort hotel is less than 7 days

# %% [markdown]
# # **Q6. Which distribution channel brings more adr-revenue generating deals for hotels?**

# %%
# Total revenue generated by each distribution channel 
dc_adr_hotel = hotel_df1.groupby(['distribution_channel','hotel'])
dc_adr_hotel_df = pd.DataFrame((dc_adr_hotel['adr']).agg(np.mean)).reset_index().rename(columns={'adr': 'Average Revenue'})

# %%
# Plotting revenue generated by each distribution channel
plt.figure(figsize = (7,5))
sns.barplot(x = dc_adr_hotel_df['distribution_channel'], y = dc_adr_hotel_df['Average Revenue'], hue = dc_adr_hotel_df['hotel'])
plt.title('Plot representing avg. adr generated by each distribution channel')
plt.ylim(40,140)
plt.show()

# %% [markdown]
# **Chart Represents :-**
#
# *   Corporate- These are corporate hotel booking companies which makes bookings
# possible.
#
# *   GDS-A GDS is a worldwide conduit between travel bookers and suppliers, such as hotels and other accommodation providers. It communicates live product, price and availability data to travel agents and online booking engines, and allows for automated transactions.
# *   Direct- means that bookings are directly made with the respective hotels
#
#
# *   TA/TO- means that bookings are made through travel agents or tour operators.
#
# *   Undefined- Bookings are undefined. may be customers made their bookings on arrival or the data get misplaced while booking.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar graph is used to compare the items between different groups over time. Bar graphs are used to measure the changes over a period of time. When the changes are larger, a bar graph is the best option to represent the data.
#
# Thus, I have used the bar plot to show the average revenue provided by different distribution channel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above analysis we can say that even if TA/TO brings more Booking to City hotels the revenue generated through this channel is very low compare to the GDS, The revenue generated from GDS is Highest. So City Hotel must reach this ditribution channel for more bookings.
#
# The resort hotel has most revenue generated by direct approach of the people & through TA/TO Channel.As we see GDS generate most revenue compare to all, the resort hotel should contact this channel more to increase their revenue.

# %% [markdown]
# #**Q7. Which month generates highest adr ?**

# %%
# group by on arrival_date_month & hotel column having avg adr
bookings_by_months_df=hotel_df1.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()
#create month list
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# it will take the order of the month list in the df along with values
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
#sortting
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')
bookings_by_months_df
# Out:
#    arrival_date_month         hotel         adr
# 8             January    City Hotel   85.515602
# 9             January  Resort Hotel   49.181693
# 6            February    City Hotel   89.371926
# 7            February  Resort Hotel   54.102809
# 15              March  Resort Hotel   57.590889
# 14              March    City Hotel   94.154306
# 0               April    City Hotel  117.438491
# 1               April  Resort Hotel   79.283805
# 17                May  Resort Hotel   80.551101
# 16                May    City Hotel  128.090815
# 13               June  Resort Hotel  112.380859
# 12               June    City Hotel  124.052052
# 11               July  Resort Hotel  156.166914
# 10               July    City Hotel  120.569091
# 3              August  Resort Hotel  187.566659
# 2              August    City Hotel  125.353829
# 22          September    City Hotel  118.759391
# 23          September  Resort Hotel  100.892331
# 20            October    City Hotel  107.678665
# ...

# %%
# set plot size and plot the line
plt.figure(figsize=(12,7))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['adr'],hue=bookings_by_months_df['hotel'])

# set lables
plt.title('ADR across each month')
plt.xlabel('Month')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %%
# Categorizing on arrival_date_month
hotel_df1['arrival_date_month'] = pd.Categorical(hotel_df1['arrival_date_month'],categories=months,ordered=True)
# Plotting the box graph for visualization 
plt.figure(figsize = (15,7))
sns.boxplot(x = hotel_df1['arrival_date_month'],y = hotel_df1['adr'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this I used two charts first line chart to get the amount varying from month-to-month & second to get clear picture of revenue for particular month even if the adr is low.
#
# Line graphs or line charts are best when you want to show how the value of something changes over time, or compare how several things change over time relative to each other. Line graphs are common and effective charts because they are simple, easy to understand, and efficient. So I used line chart to plot the total booking with repect to month of year.
#
# Box plots are used to show distributions of numeric data values, especially when you want to compare them between multiple groups. They are built to provide high-level information at a glance, offering general information about a group of data's symmetry, skew, variance, and outliers.
#
# Thus, for each month in the given dataset, I used box plot to analyse the outliers and interquartile range including mean, median, maximum and minimum value.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# For Resort hotel ADR is high in the months of June,July,August as compared to City Hotels. May be Customers/People wants to spend their Summer vaccation in Resorts Hotels.
#
# For City Hotel ADR is about average throughout the months from April to September
#
# The best time for guests to visit Resort or City hotels is January, February, March, April,October, November and December as the avrage daily rate in this month is very low.
#
# Avg adr rises from beginning of year upto middle of year and reaches peak at August and then lowers to the end of year. But hotels do make some good deals with high adr at end of year also.

# %% [markdown]
# #**Q8. Which distribution channel has the higest cancellation rate ?**

# %%
# taking only cancelled booking in dataframe
canceled_df=hotel_df1[hotel_df1['is_canceled']==1]

#group by distribution channel
canceled_df=canceled_df.groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'Counts'})
# Cancelled booking dataframe
canceled_df
# Out:
#   distribution_channel         hotel  Counts
# 0            Corporate    City Hotel     330
# 1            Corporate  Resort Hotel     316
# 2               Direct    City Hotel     963
# 3               Direct  Resort Hotel     952
# 4                  GDS    City Hotel      36
# 5                TA/TO    City Hotel   14620
# 6                TA/TO  Resort Hotel    6706
# 7            Undefined    City Hotel       4

# %%
#set plot size and plot barchart 
plt.figure(figsize=(12,6))
sns.barplot(x='distribution_channel',y='Counts',hue="hotel",data=canceled_df)

# set labels
plt.xlabel('Distribution channel')
plt.ylabel('counts')
plt.title('Cancellation Rate Vs Distribution channel')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar graph is used to compare the items between different groups over time. Bar graphs are used to measure the changes over a period of time. When the changes are larger, a bar graph is the best option to represent the data.
#
# Thus, I have used the bar plot to show from which distribution channel the cancellation rate is high.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above we can say that TA/To channel has the highest cancellation rate, While others had very low to negligible cancellation rate.
#
#
# In "TA/TO" distribution cahnnel, City hotels has the high cancellation rate(14,620) compared to resort hotels (6,706).
# In "direct" distribution channel both the hotels has almost same cancellation rate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From above analysis we can see that the most booking to the hotels are come from 'TA/To' distribution channel, The most amount of booking getting cancelled are also from 'TA/To' distribution channel.
#
# Thus hotels should try to inquire the channel for the reason behind cancellation of booking so that they can improve on that aspect or provide better service.

# %% [markdown]
# #**Q9. What if we failled to allot the guests with the same room type which was reserved by them would that lead to booking cancellation or not ?**

# %%
# Define a function for the reserved room type is same  or not as  assigned room type
def same_room_allotment(x):
  '''function to check whether the reserved room 
  type is same  or not as  assigned room type'''

  if x['reserved_room_type'] != x['assigned_room_type']:
    return 1
  else:
    return 0

# %%
# create new column to df1
hotel_df1['Same_room_alloted_or_not']=hotel_df1.apply(lambda x: same_room_allotment(x),axis=1)

#groupby is canceled
grp_by_canceled_df=hotel_df1.groupby('is_canceled')

# create DF and calculate  percentage of same room alloted  or not
DF=pd.DataFrame(grp_by_canceled_df['Same_room_alloted_or_not'].sum()*100/grp_by_canceled_df.size()).rename(columns={0:"percentage"})
DF
# Out:
#              percentage
# is_canceled
# 0             19.566286
# 1              2.570318

# %%
#set plot size and plot barchart
plt.figure(figsize=(10,6))
sns.barplot(x=DF.index,y=DF['percentage'])

# set labels
plt.title('%  of not getting the same room vs Booking cancellation')
plt.xlabel('is_canceled')
plt.ylabel('% of not getting same room as per reservation')
plt.xticks([0,1],['Not canceled','canceled'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the average percentage of number of people cancelled booking, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above we can say that even if the guests are not assigned with the same rooms which they reserved during booking it has very low effect on cancellation.
#
# Total Percentage of Guests didn't get the room type reserved by them :- **22.14%**
#
# 1.   Percent of Guests not cancelled their booking :- **19.57%**
# 2.   Percent of Guests cancelled their booking :-  **2.57%**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Not getting same room as demanded is not the case of cancellation of rooms. A significant percentage of bookings are not cancelled even after getting different room as demanded.
#
# Although, assigning different room does reduces the adr or customers who didn't got same room have paid a little lower adr.Thus Hotels should always vary & keep the data of Vacancy & Time for room availability updated at their sites as well as at other sources through which bookings came also to avoid these kind of misplacement or mis-management.
#
# Not getting same room which was reserved or on arrival had to change the booking impacts Hotel reputation alot, It also creates bad image for hotels which would leads to further cancellation of booking or customers tends to hesitate while booking in the same hotels result in getting lower booking rate.

# %% [markdown]
# #**Q10. Does lead time or number of days in waiting list motivates the customers to cancel the booking ?**

# %%
# To check we need to generate a density plot of lead time and number of days in waiting list for both cancelled and non-cancelled bookings.
fig, axes = plt.subplots(1, 2, figsize=(18, 7))
# a very high number of records have zero number of days in waiting list
# thats why here only non-zero data is considered
sns.kdeplot(data = hotel_df1[hotel_df1['days_in_waiting_list'] != 0], ax = axes[0], x = 'days_in_waiting_list', hue = 'is_canceled')
sns.kdeplot(data = hotel_df1, ax = axes[1], x = 'lead_time', hue = 'is_canceled')
plt.show()

# %% [markdown]
# **Chart Represents :-**
#
# *   0 - Booking Not Cancelled
# *   1 - Booking Cancelled

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this I used two kdeplot from seaborn for waiting time & lead time.
#
# KDE plot also known as Kernel Density Estimate Plot. It allows us to estimate the probability density function of the continuous or non-parametric from our data set curve in one or more dimensions it means we can create or plot a single graph for multiple samples which helps in more efficient data visualization.
#
# Thus, I have used the KDE plot to depict the relationship between lead time & waiting time with respect to booking cancellation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above we can say that Density plot of lead time and number of days in waiting list peaks at the same point for both cancelled and non-cancelled bookings and they also attain almost identical shape.
#
# Although, Density plot for days in waiting list & Lead time shows that there are number of people who cancel the booking within 100 days of waiting time as well as people who has more than 100 days of lead time.
# Thus some Guest generaly does have that patient while others having more lead time tends to search for better deals or cancelled their plan.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The more the waiting time the more the guest cancelled their booking. Thus hotels must procreate time management system to reduce the waiting time which creates the negative growth impact on their business.
#
# While their are huge amount of guest who did not cancelled their booking after getting huge lead time but there are some guest who cancelled their booking after getting huge lead time. So hotels should provide the lead time less than 50 or 100 days.

# %% [markdown]
# #**Q11. What is Relationship between ADR and total stay ?**

# %%
adr_vs_stay = hotel_df1.groupby(['Total_stay', 'adr','hotel']).agg('count').reset_index()
adr_vs_stay = adr_vs_stay.iloc[:, :3]
adr_vs_stay = adr_vs_stay.rename(columns={'is_canceled':'Number of stays'})
adr_vs_stay=adr_vs_stay[:18000]
adr_vs_stay
# Out:
#        Total_stay     adr         hotel
# 0               0    0.00    City Hotel
# 1               0    0.00  Resort Hotel
# 2               1    0.00    City Hotel
# 3               1    0.00  Resort Hotel
# 4               1    1.00    City Hotel
# ...           ...     ...           ...
# 17995           7  215.00  Resort Hotel
# 17996           7  215.60  Resort Hotel
# 17997           7  215.71  Resort Hotel
# 17998           7  216.00  Resort Hotel
# 17999           7  216.14  Resort Hotel
#
# [18000 rows x 3 columns]

# %%
#plot line chart
plt.figure(figsize=(10,5))
sns.lineplot(x='Total_stay',y='adr',data=adr_vs_stay)
plt.title('Relationship between adr and total stay')
plt.show()

# %%
# plotting scatter plot for better understanding
plt.figure(figsize=(16,7))
sns.scatterplot(x=hotel_df1['Total_stay'],y=hotel_df1['adr'])
plt.title('Relationship between  adr and total stay')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this I used two charts first line chart to get the ADR varying with respect to number of stay & second to get clear picture of revenue as number of stay increase for every variable.
#
# Line graphs or line charts are best when you want to show how the value of something changes over time, or compare how several things change over time relative to each other. Line graphs are common and effective charts because they are simple, easy to understand, and efficient.
#
# So I used line chart to plot the total stay with repect to ADR.
#
# A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables.
#
# Thus, I have used the scatter plot to depict the relationship between Total stay and ADR.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the first line chart we can say that as the total stay increases the adr also increases upto the point i.e. Less than 6 days. Thus Hotels generates great revenue for these amount of stay.
#
# But From above scatter chart we see that as the stay increases i.e. more than 10 days adr starts decreasing. The longer the customer stays (i.e. more than 10 days) the less revenue hotels generates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If the customer stays for less than six days the hotel generates highest amount of adr while as they start to stay more than 10 days the adr decreases drastically.
#
# Thus hotels should come up with some counter offers for longer stay, so that their adr doesn't reduce or cause any loss.
#
# For shorter stays the adr varies greatly but for longer stays (> 10 days) adr is comparatively very less. Therefore, customers can get better deal for longer stays more than 10 days.

# %% [markdown]
# #**Q12. What is the relationship between the repeated guests and previous bookings not cancelled?**

# %%
# plotting the graph for repeated guest with respect to not cancelled booking 
plt.figure(figsize=(10,5))
sns.barplot(x=hotel_df1['is_repeated_guest'],y= hotel_df1['previous_bookings_not_canceled'])
plt.xticks([0,1],['Not_repeated_guests','repeated_guests'],fontsize=15)
plt.title('Relationship Between repeated guests and previous bookings nor cancelled.')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the average percentage of number of repeated guest cancelled their booking, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above we can say that the guest who already visited the hotel before or repeated guest doesn't cancelled their booking as much due to their prior satisfactory experience with the hotel.
#
# While the guest who are not repeated tend to cancelled their booking more. Effort should be made to retain customers to reduce chance of cancellations too.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(16,10))
sns.heatmap(hotel_df1.corr(),annot=True)
plt.title('Co-relation of the columns')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation heatmaps can be used to find potential relationships between variables and to understand the strength of these relationships.
# Each cell in the table shows the correlation between two variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses. The range of correlation is [-1,1].
#
# Thus to know the correlation between all the variables along with the correlation coeficients, I used correlation heatmap.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In  the above co-relation matrix we have co-relation between different columns of Data Frame and we can compare the two columns based on their annoted values
# * The total stay has very high co-relation with stay_in_weekend_nights(**+0.78**) & stay_in_week_nights(**+0.95**). This means guest usually makes plan to stay for nights more than day-time.
#
# * is_canceled and same_room_alloted_or_not are negatively corelated. That means customer is unlikely to cancel his bookings if he don't get the same room as per reserved room. We have visualized it above.
#
# * Total stay length and lead time are positively correlated i.e. **+0.32**. This may means that for longer hotel stays, people generally plan little before the actual arrival
#
# * adults,childrens and babies are corelated to each other. That means more the people more will be adr.
#
# * is_repeated guest and previous bookings not canceled has strong corelation (**+0.44**). may be repeated guests are not more likely to cancel their bookings.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# Our business objective was to increase the Bookings, reduce the customer cancellation rate & Increase the Retention of customer as well as to increase the optimal stay while procurring the optimal adr. Based on the analysis we done above, some recommendations we came up with are as follows:
# *   To reduce the cancellation rate the hotel must provide or include a Feedback form so that they can have a idea as why the customers are cancelling the booking, on which aspects they can improve & resolve the issues if any arises, so there cancellation rate comes down.
# *   Assigning different room does reduces the adr or customers who didn't got same room have paid a little lower adr.Thus Hotels should always vary & keep the data of Vacancy & Time for room availability updated everytime at their sites as well as at other sources through which bookings came also to avoid these kind of misplacement or mis-management.
# *   Hotels must Pre-Prepped material required for BB( Bed and Breakfast) type Meal & put it on standby to reduce the delay time and better time management and also buy more ingredients which required for preparing BB type meal and average amount of material for HB- (Half Board) & SC- (Self Catering) type. Thus reducing the Wastage of Materail & reducing the Material Cost. Which will result in less wastage, better time management & increase in revenue.
# *   Sometimes, more the lead time or waiting time the more the guest cancelled their booking. Thus hotels must procreate time management system to reduce the waiting time & lead time less than 50 or 100 days.
# *   We can see that very small percentage of people required parking space.Thus Hotels can utilize this Extra space available to conduct some Party\events or entertainment events on the space accordingly, as a advertisement campaign to increase the booking or to increase the retention rate.
# *   Agents and market sectors that bring in more clients should also be recognised with awards and incentives.
# *   Extra efforts should be made to foster positive relationships with clients which can be done by keeping in touch with them by sending them engaging emails, such as "Thank you" and "Happy Holidays", or “Holiday Offers”etc.
# *   •	Data from each visitor's stay can be used to send them personalized offers to maximize their chances of booking again. By sending attractive deals such as some % of discount while booking 2nd/3rd time or giving them complimentary BB
# * Finally, with the change in time the hotels should change their campaigning & advertising strategy too.
#     * They should post more online post like Pictures of their hotels, Scenery-Views near/from their hotel, different type of delicious Food available in their hotels & update it everyday.
#     * They should start organizing events like dj-nights, outdoor camping, campfire-night,etc.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1)	City hotels are the most preferred hotel type by the guests. 61% bookings are for City hotel and 39% bookings are for Resort hotel, We can say that City Hotel is busier than Resort hotel.
#
# 2)	Lion's share of agent bookings is done by 2 agents (Agent 9 & 240 ).Also, 75% of the bookings are done by just 8 agents.Therefore there is immense scope to increase bookings by other agents.
#
# 3)	27.5 % bookings were got cancelled out of all the bookings.
#
# 4)	Only Small percentage of people were revisited the hotels, Rest were new guests. Thus retention rate is very low. Both hotels have significantly higher booking cancellation rates and very few guests less than 3 % return for another booking in City hotel. 5% guests return for stay in Resort hotel.
#
# 5)	Most of the customers (91.6%) do not require car parking spaces. Only 8.4% required one parking space.
#
# 6)	BB( Bed & Breakfast) is the most preferred type of meal by the guests.
#
# 7)	Room Type A is the most preferred room type among travellers.
#
# 8)	Maximum number of guests were from Portugal, i.e. more than 25000 guests.
#
# 9)	Average ADR for city hotel is slightly higher as compared to resort hotels. Thus Resort hotels should preferred some of the city hotel techniques which are liable to them to increase the ADR.
#
# 10)	Booking cancellation rate is high for City hotels than Resort Hotels which is almost 30%.
#
# 11)	Waiting time period for City hotel is high as compared to resort hotels. That means city hotels are much busier than Resort hotels.
#
# 12)	Guests use different channels for making bookings out of which most preferred way is TA/TO.
#
# 13)	Corporate has the most percentage of repeated guests while TA/TO has the least whereas in the case of cancelled bookings TA/TO has the most percentage while Corporate has the least.
#
# 14)	For hotels higher adr deals come via GDS channel, so hotels should increase their popularity on this channel.
#
# 15)	Almost 19 % people did not cancel their bookings even after not getting the same room which they reserved while booking hotel. Only 2.5 % people cancelled the booking.
#
# 16)	Not getting same room as reserved, Lead time, number of days in waiting list does not affect cancellation of bookings. Although different room allotment do lowers the adr.
#
# 17)	Optimal stay in both the type hotel is less than 7 days. Usually people stay for a week.
#
# 18)	The City hotel has more guests during spring and autumn, when the prices are also highest, In July and August there are less visitors, although prices are lower. Thus, customers can get good deal on bookings in July and August in city hotel.
#
# 19)	Guest numbers for the Resort hotel go down slightly from June to September, which is also when the prices are highest. Thus, these months should be avoided for bookings for customers. While the Resort Owner should address these problem & adjust the rate accordingly.
#
# 20)	May to August is the peak season of bookings for both hotels. While there are fewest guests during the winter.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
